# %%
# %%capture
import pandas as pd
from django_pandas.io import read_frame
from pathlib import Path
from dj_notebook import activate

plus = activate(dotenv_file="/Users/erikvw/source/edc_source/intecomm-edc/.env")
report_folder = Path("/Users/erikvw/Documents/ucl/protocols/intecomm/reports/")
# output is suppressed -- normally would spew out all the edc loading messages

# %%
from edc_pdutils.dataframes import get_crf

# %%
df_review = get_crf(
    "intecomm_subject.hivreview", subject_visit_model="intecomm_subject.subjectvisit"
)

# %%
df_review
